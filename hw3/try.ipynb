# %%
loss_a = [1.3636, 1.361, 1.2298, 1.2517, 1.279, 1.214, 1.1613, 1.1972, 1.1512, 1.1235]
loss_b=[1.4365, 1.4671, 1.3511, 1.3781, 1.4216, 1.3876, 1.329, 1.3718, 1.3341, 1.2952, 1.2453, 1.2757, 1.2845, 1.1837, 1.1758, 1.1048, 1.1292, 1.1533, 1.0973, 1.1092]
loss_c=[1.3317, 1.2936, 1.1847, 1.2077, 1.247, 1.2019, 1.1656, 1.2031, 1.1791, 1.1468, 1.1038, 1.1571, 1.1588, 1.0823, 1.0911, 1.0185, 1.0615, 1.0885, 1.0509, 1.0663]

# %%
import matplotlib.pyplot as plt

x = [(i+1) * 100 for i in range(len(loss_c))]
print(x)
# Create the plot
plt.plot(x, loss_c)
for i in range(len(loss_c)):
    plt.text(x[i], loss_c[i], str(loss_c[i]), ha='center', rotation=90)

# Set the x-axis ticks
plt.xticks(x, rotation=90)
# Optionally set the title and labels
plt.title('Loss over time')
plt.xlabel('Step')
plt.ylabel('Loss')

# Display the plot
plt.show()
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000]

# %%
import json
import codecs

# Open the file using codecs.open and read the data
with open("/home/guest/r12922121/ADL_2023_NTU/hw3/prediction_zero.json", 'r') as f:
    data = json.load(f)

# Write the data back to the file using codecs.open
with open('prediction_zero2.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False,indent=4)

# %%
import json
with open("/home/guest/r12922121/ADL_2023_NTU/hw3/data/train.json", 'r') as f:
    data = json.load(f)
print(len(data))
# Out:
# 10000
